# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Loading Credit Card Dataset to Pandas Dataframe

# %%
cc_df=pd.read_csv('creditcard.csv')

# %%
# printing first 5 rows 
cc_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
 # printing last 5 rows
cc_df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
cc_df.info() #printing details of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
cc_df.isnull().sum() #printing missing values in each column
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# printing number of fraudulent and legit transactions
# 0- legit transaction; 1- fraudulent transaction
cc_df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Dataset is highly unbalanced 
# separating the data
legit = cc_df[cc_df.Class==0]
fraud = cc_df[cc_df.Class==1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
# printing statistical functions for column 'Amount'
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# doing comparsion between legit and fraud data
cc_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [raw]
# There's a vast difference between both the data(shown above)

# %% [markdown]
# <!-- Now, we will be building a sample dataset containing similar distribution of both data -->

# %%
legit_sample = legit.sample(n=492) #n is number of values(here, we are taking 492; equivalent to fraud data) , it will print 492 values in random order
print(legit_sample)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 265840  162067.0  2.058436 -0.057866 -1.094902  0.392024 -0.074310 -1.087761
# 73851    55308.0 -0.868992  0.868589  1.522351 -0.873355  0.553981 -0.068083
# 249844  154606.0  0.039101  0.725403  0.184067 -0.599050  0.304179 -1.057743
# 6043      6827.0 -0.032618  1.103281  0.245374  1.446278  0.643009 -0.313290
# 65381    51557.0  1.105084 -0.135365  1.240353  1.301271 -0.857501  0.254749
# ...          ...       ...       ...       ...       ...       ...       ...
# 219192  141635.0 -0.815933 -0.971989  1.217234 -2.203182  0.198365 -0.534557
# 129826   79221.0  1.227071 -0.404910  0.794848 -0.918535 -0.988407 -0.311474
# 138078   82475.0 -1.726939  2.093222  0.771912 -0.151835 -0.403555 -0.327853
# 256099  157538.0 -0.779697  1.278852 -2.457849 -0.940651  0.913530 -1.148948
# 28359    34971.0  1.062598  0.168094  0.062292  1.026683  0.659923  1.147262
#
# ...

# %%
# concatenating two dataframes into new dataset
new_ds = pd.concat([legit_sample, fraud], axis=0) #axis = 0 means, values will be added row-wise

# %%
new_ds.head() #printing first 5 rows from new dataset
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 265840  162067.0  2.058436 -0.057866 -1.094902  0.392024 -0.074310 -1.087761
# 73851    55308.0 -0.868992  0.868589  1.522351 -0.873355  0.553981 -0.068083
# 249844  154606.0  0.039101  0.725403  0.184067 -0.599050  0.304179 -1.057743
# 6043      6827.0 -0.032618  1.103281  0.245374  1.446278  0.643009 -0.313290
# 65381    51557.0  1.105084 -0.135365  1.240353  1.301271 -0.857501  0.254749
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 265840  0.171460 -0.307035  0.538453  ... -0.287536 -0.684988  0.337729
# 73851   0.774712 -0.000478 -0.117477  ... -0.184565 -0.480399 -0.089225
# 249844  0.944474 -0.113625  0.196766  ... -0.282164 -0.726468  0.094628
# 6043    0.865261 -1.297790  0.807341  ...  0.704958  0.342012  0.173063
# 65381  -0.681520  0.268049  0.991148  ... -0.041358  0.083939  0.031654
#
# ...

# %%
new_ds.tail() #printing last 5 rows
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_ds['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_ds.groupby('Class').mean() #comparison of new dataset
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95036.004065  0.058366 -0.074040  0.092168 -0.016898  0.098061
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.096267  0.047440 -0.010460 -0.053614  ... -0.038111 -0.000716
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.046259 -0.012463 -0.015276  0.014541  0.001328 -0.011717  0.000590
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       79.468557
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into features and targets

# %%
#dropping column 'Class' and storing in y
x=new_ds.drop(columns='Class', axis=1) 
y=new_ds['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 265840  162067.0  2.058436 -0.057866 -1.094902  0.392024 -0.074310 -1.087761
# 73851    55308.0 -0.868992  0.868589  1.522351 -0.873355  0.553981 -0.068083
# 249844  154606.0  0.039101  0.725403  0.184067 -0.599050  0.304179 -1.057743
# 6043      6827.0 -0.032618  1.103281  0.245374  1.446278  0.643009 -0.313290
# 65381    51557.0  1.105084 -0.135365  1.240353  1.301271 -0.857501  0.254749
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(y)
# Out:
# 265840    0
# 73851     0
# 249844    0
# 6043      0
# 65381     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# Splitting data into Training and Testing data

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, stratify=y, random_state=2)
#20% of data goes to testing data and rest 80% to training data

# %%
print(x.shape, x_test.shape, x_train.shape)
# Out:
# (984, 30) (197, 30) (787, 30)

# %% [markdown]
# Model Training using Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /Users/vartikabg/Desktop/venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Evaluating model using Accuracy Score

# %%
# Training data
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print("Accuracy score on training data:",training_data_accuracy)
# Out:
# Accuracy score on training data: 0.9440914866581956

# %%
# Testing data
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print("Accuracy score on testing data:",test_data_accuracy)
# Out:
# Accuracy score on testing data: 0.9238578680203046
